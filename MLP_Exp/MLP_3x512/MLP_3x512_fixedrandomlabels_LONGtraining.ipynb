# %%
import os
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Subset

from torchvision import datasets
from torchvision import transforms

import matplotlib.pyplot as plt
from PIL import Image

import math
import copy

from google.colab import drive
drive.mount('/content/drive')

class MLP(nn.Module):
  def __init__(self, n_units, init_scale=1.0):
    super(MLP, self).__init__()

    self._n_units = copy.copy(n_units)
    self._layers = []
    for i in range(1, len(n_units)):
      layer = nn.Linear(n_units[i-1], n_units[i], bias=False)
      variance = math.sqrt(2.0 / (n_units[i-1] + n_units[i]))
      layer.weight.data.normal_(0.0, init_scale * variance)
      self._layers.append(layer)

      name = 'fc%d' % i
      if i == len(n_units) - 1:
        name = 'fc'  # the prediction layer is just called fc
      self.add_module(name, layer)


  def forward(self, x):
    x = x.view(-1, self._n_units[0])
    out = self._layers[0](x)
    for layer in self._layers[1:]:
      out = F.relu(out)
      out = layer(out)
    return out
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/'My Drive'
# Out:
# /content/drive/My Drive

# %%
def get_data(seed):
  normalize = transforms.Normalize(mean=[x/255.0 for x in [125.3, 123.0, 113.9]], std=[x / 255.0 for x in [63.0, 62.1, 66.7]])
  transform_train = transforms.Compose([
          transforms.ToTensor(),
          normalize])
  transform_test = transforms.Compose([
        transforms.ToTensor(),
        normalize])
  train_dataset = datasets.CIFAR10(root='data', 
                                train=True, 
                                transform=transform_train,
                                download=True)
  test_dataset = datasets.CIFAR10(root='data', 
                                train=False, 
                                transform=transform_test,
                                download=True)
  np.random.seed(seed)

  probability_of_random = 1.0
  labels = np.array(train_dataset.targets) 
  mask = np.random.rand(len(labels)) <= probability_of_random #create mask of length labels, where entries drawn from [0,1].
  rnd_labels = np.random.choice(10, mask.sum())               #create random labels 1-10 of length of mask
  labels[mask] = rnd_labels
  labels = [int(x) for x in labels]
  train_dataset.targets = labels                              #assign new random labels to dataset
  
  train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=128,
                          num_workers=4,
                          shuffle=True)
  test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=128,
                         num_workers=4,
                         shuffle=False)
  return train_loader, test_loader

# %%
def compute_acc(model, data_loader):
    correct_pred, num_examples = 0, 0
    model.eval()
    for i, (features, targets) in enumerate(data_loader):
        features, targets = features.to(device), targets.to(device)
        probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        assert predicted_labels.size() == targets.size()
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100

# %%
criterion = nn.CrossEntropyLoss()

epoch_max = 400

train_loader, test_loader = get_data(0) #fix the seed of the random labels 

torch.manual_seed(0) #iterate through 10 random inits
mlp_spec = '512x512x512'
n_units = [int(x) for x in mlp_spec.split('x')] # hidden dims
n_units.append(10)  # output dim
n_units.insert(0, 32*32*3)        # input dim
model = MLP(n_units)
optimizer = torch.optim.SGD(model.parameters(), .01, momentum=0.9, weight_decay=0)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, [50, 100, 150, 200, 250, 300, 350], gamma=0.1, last_epoch=-1)

cost_list = []
train_acc_list = []

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

  

for epoch in range(epoch_max):
  model.train()
  for batch_idx, (features, targets) in enumerate(train_loader):
    # compute output
    features, targets = features.to(device), targets.to(device)
    output = model(features)
    loss = criterion(output, targets)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    cost_list.append(loss.item())
    if not batch_idx % 150:
      print (f'Epoch: {epoch+1:03d}/{epoch_max:03d} | '
                  f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                  f' Cost: {loss:.4f} |'
                  f'Seed {0:03d} |' )
  if epoch % 10 == 0:
        torch.save(model, 'MLP_3x512_fixedrandom_iter0_LongTraining')
  model.eval()
  with torch.set_grad_enabled(False): # save memory during inference
    train_acc = compute_acc(model, train_loader)        
    print(f'Epoch: {epoch+1:03d}/{epoch_max:03d}\n'
              f'Train ACC: {train_acc:.2f}')
    train_acc = train_acc.cpu()
    train_acc_list.append(train_acc)
    zero = torch.Tensor([0.0])
    if torch.allclose(train_acc, zero):
      torch.save(model, 'MLP_3x512_fixedrandom_iter0_LongTraining')
  scheduler.step()

np.save('MLP_3x512_fixedrandom_iter0_LongTraining', cost_list)
np.save('MLP_3x512_fixedrandom_iter0_LongTraining', train_acc_list)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 001/400 | Batch 000/391 | Cost: 2.4999 |Seed 000 |
# Epoch: 001/400 | Batch 150/391 | Cost: 2.2990 |Seed 000 |
# Epoch: 001/400 | Batch 300/391 | Cost: 2.3242 |Seed 000 |
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:360: UserWarning: Couldn't retrieve source code for container of type MLP. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch: 001/400
# Train ACC: 14.09
# Epoch: 002/400 | Batch 000/391 | Cost: 2.2917 |Seed 000 |
# Epoch: 002/400 | Batch 150/391 | Cost: 2.3049 |Seed 000 |
# Epoch: 002/400 | Batch 300/391 | Cost: 2.2887 |Seed 000 |
# Epoch: 002/400
# Train ACC: 16.23
# Epoch: 003/400 | Batch 000/391 | Cost: 2.2854 |Seed 000 |
# Epoch: 003/400 | Batch 150/391 | Cost: 2.2646 |Seed 000 |
# Epoch: 003/400 | Batch 300/391 | Cost: 2.2833 |Seed 000 |
# Epoch: 003/400
# Train ACC: 19.12
# Epoch: 004/400 | Batch 000/391 | Cost: 2.2517 |Seed 000 |
# Epoch: 004/400 | Batch 150/391 | Cost: 2.2360 |Seed 000 |
# Epoch: 004/400 | Batch 300/391 | Cost: 2.2507 |Seed 000 |
# Epoch: 004/400
# Train ACC: 20.65
# Epoch: 005/400 | Batch 000/391 | Cost: 2.1504 |Seed 000 |
# Epoch: 005/400 | Batch 150/391 | Cost: 2.2070 |Seed 000 |
# Epoch: 005/400 | Batch 300/391 | Cost: 2.2411 |Seed 000 |
# Epoch: 005/400
# Train ACC: 23.58
# Epoch: 006/400 | Batch 000/391 | Cost: 2.1496 |Seed 000 |
# Epoch: 006/400 | Batch 150/391 | Cost: 2.1605 |Seed 000 |
# Epoch: 006/400 | Batch 300/391 | Cost: 2.1743 |Seed 000 |
# Epoch: 006/400
# Train ACC: 27.05
# Epoch: 007/400 | Batch 000/391 | Cost: 2.0551 |Seed 000 |
# Epoch: 007/400 | Batch 150/391 | Cost: 2.1138 |Seed 000 |
# Epoch: 007/400 | Batch 300/391 | Cost: 2.1965 |Seed 000 |
# Epoch: 007/400
# Train ACC: 29.78
# Epoch: 008/400 | Batch 000/391 | Cost: 2.0425 |Seed 000 |
# Epoch: 008/400 | Batch 150/391 | Cost: 2.0819 |Seed 000 |
# Epoch: 008/400 | Batch 300/391 | Cost: 2.0437 |Seed 000 |
# Epoch: 008/400
# Train ACC: 32.29
# Epoch: 009/400 | Batch 000/391 | Cost: 1.9201 |Seed 000 |
# Epoch: 009/400 | Batch 150/391 | Cost: 1.9546 |Seed 000 |
# Epoch: 009/400 | Batch 300/391 | Cost: 2.0956 |Seed 000 |
# Epoch: 009/400
# Train ACC: 34.73
# Epoch: 010/400 | Batch 000/391 | Cost: 1.8664 |Seed 000 |
# Epoch: 010/400 | Batch 150/391 | Cost: 1.9931 |Seed 000 |
# Epoch: 010/400 | Batch 300/391 | Cost: 1.9763 |Seed 000 |
# Epoch: 010/400
# Train ACC: 40.67
# Epoch: 011/400 | Batch 000/391 | Cost: 1.8203 |Seed 000 |
# Epoch: 011/400 | Batch 150/391 | Cost: 1.7112 |Seed 000 |
# Epoch: 011/400 | Batch 300/391 | Cost: 1.8703 |Seed 000 |
# Epoch: 011/400
# Train ACC: 43.94
# Epoch: 012/400 | Batch 000/391 | Cost: 1.6528 |Seed 000 |
# Epoch: 012/400 | Batch 150/391 | Cost: 1.7250 |Seed 000 |
# Epoch: 012/400 | Batch 300/391 | Cost: 1.8800 |Seed 000 |
# Epoch: 012/400
# Train ACC: 47.93
# Epoch: 013/400 | Batch 000/391 | Cost: 1.6340 |Seed 000 |
# Epoch: 013/400 | Batch 150/391 | Cost: 1.7613 |Seed 000 |
# Epoch: 013/400 | Batch 300/391 | Cost: 1.6133 |Seed 000 |
# Epoch: 013/400
# Train ACC: 51.63
# Epoch: 014/400 | Batch 000/391 | Cost: 1.5088 |Seed 000 |
# Epoch: 014/400 | Batch 150/391 | Cost: 1.5238 |Seed 000 |
# Epoch: 014/400 | Batch 300/391 | Cost: 1.4916 |Seed 000 |
# Epoch: 014/400
# Train ACC: 55.95
# Epoch: 015/400 | Batch 000/391 | Cost: 1.2161 |Seed 000 |
# Epoch: 015/400 | Batch 150/391 | Cost: 1.4770 |Seed 000 |
# Epoch: 015/400 | Batch 300/391 | Cost: 1.4079 |Seed 000 |
# Epoch: 015/400
# Train ACC: 58.17
# Epoch: 016/400 | Batch 000/391 | Cost: 1.1388 |Seed 000 |
# Epoch: 016/400 | Batch 150/391 | Cost: 1.5316 |Seed 000 |
# Epoch: 016/400 | Batch 300/391 | Cost: 1.3145 |Seed 000 |
# Epoch: 016/400
# Train ACC: 61.78
# Epoch: 017/400 | Batch 000/391 | Cost: 1.2016 |Seed 000 |
# Epoch: 017/400 | Batch 150/391 | Cost: 1.0819 |Seed 000 |
# Epoch: 017/400 | Batch 300/391 | Cost: 1.3390 |Seed 000 |
# Epoch: 017/400
# Train ACC: 63.47
# Epoch: 018/400 | Batch 000/391 | Cost: 1.0658 |Seed 000 |
# Epoch: 018/400 | Batch 150/391 | Cost: 1.0450 |Seed 000 |
# Epoch: 018/400 | Batch 300/391 | Cost: 1.1920 |Seed 000 |
# Epoch: 018/400
# Train ACC: 67.13
# Epoch: 019/400 | Batch 000/391 | Cost: 1.0327 |Seed 000 |
# Epoch: 019/400 | Batch 150/391 | Cost: 0.9933 |Seed 000 |
# Epoch: 019/400 | Batch 300/391 | Cost: 1.2240 |Seed 000 |
# Epoch: 019/400
# Train ACC: 68.37
# Epoch: 020/400 | Batch 000/391 | Cost: 1.0115 |Seed 000 |
# Epoch: 020/400 | Batch 150/391 | Cost: 0.7934 |Seed 000 |
# Epoch: 020/400 | Batch 300/391 | Cost: 0.9680 |Seed 000 |
# Epoch: 020/400
# Train ACC: 70.29
# Epoch: 021/400 | Batch 000/391 | Cost: 0.7977 |Seed 000 |
# Epoch: 021/400 | Batch 150/391 | Cost: 0.9608 |Seed 000 |
# Epoch: 021/400 | Batch 300/391 | Cost: 0.8618 |Seed 000 |
# Epoch: 021/400
# Train ACC: 72.35
# Epoch: 022/400 | Batch 000/391 | Cost: 0.7933 |Seed 000 |
# Epoch: 022/400 | Batch 150/391 | Cost: 0.7863 |Seed 000 |
# Epoch: 022/400 | Batch 300/391 | Cost: 0.9138 |Seed 000 |
# Epoch: 022/400
# Train ACC: 74.65
# Epoch: 023/400 | Batch 000/391 | Cost: 0.6716 |Seed 000 |
# Epoch: 023/400 | Batch 150/391 | Cost: 0.8200 |Seed 000 |
# Epoch: 023/400 | Batch 300/391 | Cost: 1.1593 |Seed 000 |
# Epoch: 023/400
# Train ACC: 75.03
# Epoch: 024/400 | Batch 000/391 | Cost: 0.7849 |Seed 000 |
# Epoch: 024/400 | Batch 150/391 | Cost: 0.7703 |Seed 000 |
# Epoch: 024/400 | Batch 300/391 | Cost: 0.7797 |Seed 000 |
# Epoch: 024/400
# Train ACC: 76.42
# Epoch: 025/400 | Batch 000/391 | Cost: 0.7824 |Seed 000 |
# Epoch: 025/400 | Batch 150/391 | Cost: 0.5669 |Seed 000 |
# Epoch: 025/400 | Batch 300/391 | Cost: 0.7818 |Seed 000 |
# Epoch: 025/400
# Train ACC: 78.64
# Epoch: 026/400 | Batch 000/391 | Cost: 0.7470 |Seed 000 |
# Epoch: 026/400 | Batch 150/391 | Cost: 0.6590 |Seed 000 |
# Epoch: 026/400 | Batch 300/391 | Cost: 0.6841 |Seed 000 |
# Epoch: 026/400
# Train ACC: 78.45
# Epoch: 027/400 | Batch 000/391 | Cost: 0.5587 |Seed 000 |
# Epoch: 027/400 | Batch 150/391 | Cost: 0.7274 |Seed 000 |
# Epoch: 027/400 | Batch 300/391 | Cost: 0.6736 |Seed 000 |
# Epoch: 027/400
# Train ACC: 80.11
# Epoch: 028/400 | Batch 000/391 | Cost: 0.5121 |Seed 000 |
# Epoch: 028/400 | Batch 150/391 | Cost: 0.5941 |Seed 000 |
# Epoch: 028/400 | Batch 300/391 | Cost: 0.7416 |Seed 000 |
# Epoch: 028/400
# Train ACC: 81.09
# Epoch: 029/400 | Batch 000/391 | Cost: 0.4763 |Seed 000 |
# Epoch: 029/400 | Batch 150/391 | Cost: 0.6577 |Seed 000 |
# Epoch: 029/400 | Batch 300/391 | Cost: 0.5506 |Seed 000 |
# Epoch: 029/400
# Train ACC: 83.12
# Epoch: 030/400 | Batch 000/391 | Cost: 0.5716 |Seed 000 |
# Epoch: 030/400 | Batch 150/391 | Cost: 0.4664 |Seed 000 |
# Epoch: 030/400 | Batch 300/391 | Cost: 0.4677 |Seed 000 |
# Epoch: 030/400
# Train ACC: 83.54
# Epoch: 031/400 | Batch 000/391 | Cost: 0.6087 |Seed 000 |
# Epoch: 031/400 | Batch 150/391 | Cost: 0.4617 |Seed 000 |
# Epoch: 031/400 | Batch 300/391 | Cost: 0.7465 |Seed 000 |
# Epoch: 031/400
# Train ACC: 84.64
# Epoch: 032/400 | Batch 000/391 | Cost: 0.4778 |Seed 000 |
# Epoch: 032/400 | Batch 150/391 | Cost: 0.4952 |Seed 000 |
# Epoch: 032/400 | Batch 300/391 | Cost: 0.6200 |Seed 000 |
# Epoch: 032/400
# Train ACC: 83.42
# Epoch: 033/400 | Batch 000/391 | Cost: 0.6158 |Seed 000 |
# Epoch: 033/400 | Batch 150/391 | Cost: 0.4016 |Seed 000 |
# Epoch: 033/400 | Batch 300/391 | Cost: 0.5798 |Seed 000 |
# Epoch: 033/400
# Train ACC: 83.75
# Epoch: 034/400 | Batch 000/391 | Cost: 0.5233 |Seed 000 |
# Epoch: 034/400 | Batch 150/391 | Cost: 0.3283 |Seed 000 |
# Epoch: 034/400 | Batch 300/391 | Cost: 0.4514 |Seed 000 |
# Epoch: 034/400
# Train ACC: 84.14
# Epoch: 035/400 | Batch 000/391 | Cost: 0.3980 |Seed 000 |
# Epoch: 035/400 | Batch 150/391 | Cost: 0.3784 |Seed 000 |
# Epoch: 035/400 | Batch 300/391 | Cost: 0.3695 |Seed 000 |
# Epoch: 035/400
# Train ACC: 85.96
# Epoch: 036/400 | Batch 000/391 | Cost: 0.3939 |Seed 000 |
# Epoch: 036/400 | Batch 150/391 | Cost: 0.5001 |Seed 000 |
# Epoch: 036/400 | Batch 300/391 | Cost: 0.5623 |Seed 000 |
# Epoch: 036/400
# Train ACC: 86.57
# Epoch: 037/400 | Batch 000/391 | Cost: 0.3275 |Seed 000 |
# Epoch: 037/400 | Batch 150/391 | Cost: 0.3591 |Seed 000 |
# Epoch: 037/400 | Batch 300/391 | Cost: 0.4379 |Seed 000 |
# Epoch: 037/400
# Train ACC: 85.31
# Epoch: 038/400 | Batch 000/391 | Cost: 0.6013 |Seed 000 |
# Epoch: 038/400 | Batch 150/391 | Cost: 0.3248 |Seed 000 |
# Epoch: 038/400 | Batch 300/391 | Cost: 0.4104 |Seed 000 |
# Epoch: 038/400
# Train ACC: 87.19
# Epoch: 039/400 | Batch 000/391 | Cost: 0.3178 |Seed 000 |
# Epoch: 039/400 | Batch 150/391 | Cost: 0.3569 |Seed 000 |
# Epoch: 039/400 | Batch 300/391 | Cost: 0.4252 |Seed 000 |
# Epoch: 039/400
# Train ACC: 88.80
# Epoch: 040/400 | Batch 000/391 | Cost: 0.4321 |Seed 000 |
# Epoch: 040/400 | Batch 150/391 | Cost: 0.2563 |Seed 000 |
# Epoch: 040/400 | Batch 300/391 | Cost: 0.5124 |Seed 000 |
# Epoch: 040/400
# Train ACC: 88.79
# Epoch: 041/400 | Batch 000/391 | Cost: 0.2743 |Seed 000 |
# Epoch: 041/400 | Batch 150/391 | Cost: 0.3415 |Seed 000 |
# Epoch: 041/400 | Batch 300/391 | Cost: 0.4137 |Seed 000 |
# Epoch: 041/400
# Train ACC: 89.52
# Epoch: 042/400 | Batch 000/391 | Cost: 0.2789 |Seed 000 |
# Epoch: 042/400 | Batch 150/391 | Cost: 0.1730 |Seed 000 |
# Epoch: 042/400 | Batch 300/391 | Cost: 0.4525 |Seed 000 |
# Epoch: 042/400
# Train ACC: 88.86
# Epoch: 043/400 | Batch 000/391 | Cost: 0.4701 |Seed 000 |
# Epoch: 043/400 | Batch 150/391 | Cost: 0.4907 |Seed 000 |
# Epoch: 043/400 | Batch 300/391 | Cost: 0.7756 |Seed 000 |
# Epoch: 043/400
# Train ACC: 87.74
# Epoch: 044/400 | Batch 000/391 | Cost: 0.3728 |Seed 000 |
# Epoch: 044/400 | Batch 150/391 | Cost: 0.4287 |Seed 000 |
# Epoch: 044/400 | Batch 300/391 | Cost: 0.4297 |Seed 000 |
# Epoch: 044/400
# Train ACC: 89.51
# Epoch: 045/400 | Batch 000/391 | Cost: 0.4881 |Seed 000 |
# Epoch: 045/400 | Batch 150/391 | Cost: 0.1752 |Seed 000 |
# Epoch: 045/400 | Batch 300/391 | Cost: 0.2600 |Seed 000 |
# Epoch: 045/400
# Train ACC: 88.32
# Epoch: 046/400 | Batch 000/391 | Cost: 0.2362 |Seed 000 |
# Epoch: 046/400 | Batch 150/391 | Cost: 0.1991 |Seed 000 |
# Epoch: 046/400 | Batch 300/391 | Cost: 0.3218 |Seed 000 |
# Epoch: 046/400
# Train ACC: 90.81
# Epoch: 047/400 | Batch 000/391 | Cost: 0.3033 |Seed 000 |
# Epoch: 047/400 | Batch 150/391 | Cost: 0.4357 |Seed 000 |
# Epoch: 047/400 | Batch 300/391 | Cost: 0.2750 |Seed 000 |
# Epoch: 047/400
# Train ACC: 91.22
# Epoch: 048/400 | Batch 000/391 | Cost: 0.3357 |Seed 000 |
# Epoch: 048/400 | Batch 150/391 | Cost: 0.2701 |Seed 000 |
# Epoch: 048/400 | Batch 300/391 | Cost: 0.4262 |Seed 000 |
# Epoch: 048/400
# Train ACC: 91.09
# Epoch: 049/400 | Batch 000/391 | Cost: 0.2726 |Seed 000 |
# Epoch: 049/400 | Batch 150/391 | Cost: 0.4350 |Seed 000 |
# Epoch: 049/400 | Batch 300/391 | Cost: 0.2671 |Seed 000 |
# Epoch: 049/400
# Train ACC: 91.35
# Epoch: 050/400 | Batch 000/391 | Cost: 0.2008 |Seed 000 |
# Epoch: 050/400 | Batch 150/391 | Cost: 0.3268 |Seed 000 |
# Epoch: 050/400 | Batch 300/391 | Cost: 0.2585 |Seed 000 |
# Epoch: 050/400
# Train ACC: 90.17
# Epoch: 051/400 | Batch 000/391 | Cost: 0.3569 |Seed 000 |
# Epoch: 051/400 | Batch 150/391 | Cost: 0.1199 |Seed 000 |
# Epoch: 051/400 | Batch 300/391 | Cost: 0.1029 |Seed 000 |
# Epoch: 051/400
# Train ACC: 98.67
# Epoch: 052/400 | Batch 000/391 | Cost: 0.0824 |Seed 000 |
# Epoch: 052/400 | Batch 150/391 | Cost: 0.0418 |Seed 000 |
# Epoch: 052/400 | Batch 300/391 | Cost: 0.0654 |Seed 000 |
# Epoch: 052/400
# Train ACC: 99.08
# Epoch: 053/400 | Batch 000/391 | Cost: 0.0226 |Seed 000 |
# Epoch: 053/400 | Batch 150/391 | Cost: 0.0105 |Seed 000 |
# Epoch: 053/400 | Batch 300/391 | Cost: 0.0596 |Seed 000 |
# Epoch: 053/400
# Train ACC: 99.23
# Epoch: 054/400 | Batch 000/391 | Cost: 0.0506 |Seed 000 |
# Epoch: 054/400 | Batch 150/391 | Cost: 0.0432 |Seed 000 |
# Epoch: 054/400 | Batch 300/391 | Cost: 0.0223 |Seed 000 |
# Epoch: 054/400
# Train ACC: 99.33
# Epoch: 055/400 | Batch 000/391 | Cost: 0.0614 |Seed 000 |
# Epoch: 055/400 | Batch 150/391 | Cost: 0.0301 |Seed 000 |
# Epoch: 055/400 | Batch 300/391 | Cost: 0.0372 |Seed 000 |
# Epoch: 055/400
# Train ACC: 99.39
# Epoch: 056/400 | Batch 000/391 | Cost: 0.0169 |Seed 000 |
# Epoch: 056/400 | Batch 150/391 | Cost: 0.0341 |Seed 000 |
# Epoch: 056/400 | Batch 300/391 | Cost: 0.0464 |Seed 000 |
# Epoch: 056/400
# Train ACC: 99.47
# Epoch: 057/400 | Batch 000/391 | Cost: 0.0349 |Seed 000 |
# Epoch: 057/400 | Batch 150/391 | Cost: 0.0116 |Seed 000 |
# Epoch: 057/400 | Batch 300/391 | Cost: 0.0384 |Seed 000 |
# Epoch: 057/400
# Train ACC: 99.53
# Epoch: 058/400 | Batch 000/391 | Cost: 0.0157 |Seed 000 |
# Epoch: 058/400 | Batch 150/391 | Cost: 0.0265 |Seed 000 |
# Epoch: 058/400 | Batch 300/391 | Cost: 0.0149 |Seed 000 |
# Epoch: 058/400
# Train ACC: 99.57
# Epoch: 059/400 | Batch 000/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 059/400 | Batch 150/391 | Cost: 0.0096 |Seed 000 |
# Epoch: 059/400 | Batch 300/391 | Cost: 0.0225 |Seed 000 |
# Epoch: 059/400
# Train ACC: 99.59
# Epoch: 060/400 | Batch 000/391 | Cost: 0.0152 |Seed 000 |
# Epoch: 060/400 | Batch 150/391 | Cost: 0.0436 |Seed 000 |
# Epoch: 060/400 | Batch 300/391 | Cost: 0.0255 |Seed 000 |
# Epoch: 060/400
# Train ACC: 99.62
# Epoch: 061/400 | Batch 000/391 | Cost: 0.0470 |Seed 000 |
# Epoch: 061/400 | Batch 150/391 | Cost: 0.0258 |Seed 000 |
# Epoch: 061/400 | Batch 300/391 | Cost: 0.0316 |Seed 000 |
# Epoch: 061/400
# Train ACC: 99.65
# Epoch: 062/400 | Batch 000/391 | Cost: 0.0360 |Seed 000 |
# Epoch: 062/400 | Batch 150/391 | Cost: 0.0430 |Seed 000 |
# Epoch: 062/400 | Batch 300/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 062/400
# Train ACC: 99.65
# Epoch: 063/400 | Batch 000/391 | Cost: 0.0246 |Seed 000 |
# Epoch: 063/400 | Batch 150/391 | Cost: 0.0223 |Seed 000 |
# Epoch: 063/400 | Batch 300/391 | Cost: 0.0332 |Seed 000 |
# Epoch: 063/400
# Train ACC: 99.69
# Epoch: 064/400 | Batch 000/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 064/400 | Batch 150/391 | Cost: 0.0259 |Seed 000 |
# Epoch: 064/400 | Batch 300/391 | Cost: 0.0167 |Seed 000 |
# Epoch: 064/400
# Train ACC: 99.71
# Epoch: 065/400 | Batch 000/391 | Cost: 0.0080 |Seed 000 |
# Epoch: 065/400 | Batch 150/391 | Cost: 0.0050 |Seed 000 |
# Epoch: 065/400 | Batch 300/391 | Cost: 0.0107 |Seed 000 |
# Epoch: 065/400
# Train ACC: 99.73
# Epoch: 066/400 | Batch 000/391 | Cost: 0.0335 |Seed 000 |
# Epoch: 066/400 | Batch 150/391 | Cost: 0.0214 |Seed 000 |
# Epoch: 066/400 | Batch 300/391 | Cost: 0.0293 |Seed 000 |
# Epoch: 066/400
# Train ACC: 99.74
# Epoch: 067/400 | Batch 000/391 | Cost: 0.0469 |Seed 000 |
# Epoch: 067/400 | Batch 150/391 | Cost: 0.0107 |Seed 000 |
# Epoch: 067/400 | Batch 300/391 | Cost: 0.0133 |Seed 000 |
# Epoch: 067/400
# Train ACC: 99.75
# Epoch: 068/400 | Batch 000/391 | Cost: 0.0219 |Seed 000 |
# Epoch: 068/400 | Batch 150/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 068/400 | Batch 300/391 | Cost: 0.0287 |Seed 000 |
# Epoch: 068/400
# Train ACC: 99.78
# Epoch: 069/400 | Batch 000/391 | Cost: 0.0164 |Seed 000 |
# Epoch: 069/400 | Batch 150/391 | Cost: 0.0221 |Seed 000 |
# Epoch: 069/400 | Batch 300/391 | Cost: 0.0067 |Seed 000 |
# Epoch: 069/400
# Train ACC: 99.79
# Epoch: 070/400 | Batch 000/391 | Cost: 0.0147 |Seed 000 |
# Epoch: 070/400 | Batch 150/391 | Cost: 0.0445 |Seed 000 |
# Epoch: 070/400 | Batch 300/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 070/400
# Train ACC: 99.79
# Epoch: 071/400 | Batch 000/391 | Cost: 0.0032 |Seed 000 |
# Epoch: 071/400 | Batch 150/391 | Cost: 0.0141 |Seed 000 |
# Epoch: 071/400 | Batch 300/391 | Cost: 0.0116 |Seed 000 |
# Epoch: 071/400
# Train ACC: 99.81
# Epoch: 072/400 | Batch 000/391 | Cost: 0.0246 |Seed 000 |
# Epoch: 072/400 | Batch 150/391 | Cost: 0.0281 |Seed 000 |
# Epoch: 072/400 | Batch 300/391 | Cost: 0.0204 |Seed 000 |
# Epoch: 072/400
# Train ACC: 99.82
# Epoch: 073/400 | Batch 000/391 | Cost: 0.0071 |Seed 000 |
# Epoch: 073/400 | Batch 150/391 | Cost: 0.0273 |Seed 000 |
# Epoch: 073/400 | Batch 300/391 | Cost: 0.0305 |Seed 000 |
# Epoch: 073/400
# Train ACC: 99.83
# Epoch: 074/400 | Batch 000/391 | Cost: 0.0174 |Seed 000 |
# Epoch: 074/400 | Batch 150/391 | Cost: 0.0138 |Seed 000 |
# Epoch: 074/400 | Batch 300/391 | Cost: 0.0059 |Seed 000 |
# Epoch: 074/400
# Train ACC: 99.85
# Epoch: 075/400 | Batch 000/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 075/400 | Batch 150/391 | Cost: 0.0107 |Seed 000 |
# Epoch: 075/400 | Batch 300/391 | Cost: 0.0212 |Seed 000 |
# Epoch: 075/400
# Train ACC: 99.86
# Epoch: 076/400 | Batch 000/391 | Cost: 0.0185 |Seed 000 |
# Epoch: 076/400 | Batch 150/391 | Cost: 0.0083 |Seed 000 |
# Epoch: 076/400 | Batch 300/391 | Cost: 0.0233 |Seed 000 |
# Epoch: 076/400
# Train ACC: 99.86
# Epoch: 077/400 | Batch 000/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 077/400 | Batch 150/391 | Cost: 0.0253 |Seed 000 |
# Epoch: 077/400 | Batch 300/391 | Cost: 0.0073 |Seed 000 |
# Epoch: 077/400
# Train ACC: 99.86
# Epoch: 078/400 | Batch 000/391 | Cost: 0.0108 |Seed 000 |
# Epoch: 078/400 | Batch 150/391 | Cost: 0.0010 |Seed 000 |
# Epoch: 078/400 | Batch 300/391 | Cost: 0.0082 |Seed 000 |
# Epoch: 078/400
# Train ACC: 99.87
# Epoch: 079/400 | Batch 000/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 079/400 | Batch 150/391 | Cost: 0.0068 |Seed 000 |
# Epoch: 079/400 | Batch 300/391 | Cost: 0.0258 |Seed 000 |
# Epoch: 079/400
# Train ACC: 99.88
# Epoch: 080/400 | Batch 000/391 | Cost: 0.0084 |Seed 000 |
# Epoch: 080/400 | Batch 150/391 | Cost: 0.0190 |Seed 000 |
# Epoch: 080/400 | Batch 300/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 080/400
# Train ACC: 99.89
# Epoch: 081/400 | Batch 000/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 081/400 | Batch 150/391 | Cost: 0.0052 |Seed 000 |
# Epoch: 081/400 | Batch 300/391 | Cost: 0.0049 |Seed 000 |
# Epoch: 081/400
# Train ACC: 99.88
# Epoch: 082/400 | Batch 000/391 | Cost: 0.0105 |Seed 000 |
# Epoch: 082/400 | Batch 150/391 | Cost: 0.0181 |Seed 000 |
# Epoch: 082/400 | Batch 300/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 082/400
# Train ACC: 99.89
# Epoch: 083/400 | Batch 000/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 083/400 | Batch 150/391 | Cost: 0.0100 |Seed 000 |
# Epoch: 083/400 | Batch 300/391 | Cost: 0.0129 |Seed 000 |
# Epoch: 083/400
# Train ACC: 99.89
# Epoch: 084/400 | Batch 000/391 | Cost: 0.0099 |Seed 000 |
# Epoch: 084/400 | Batch 150/391 | Cost: 0.0144 |Seed 000 |
# Epoch: 084/400 | Batch 300/391 | Cost: 0.0135 |Seed 000 |
# Epoch: 084/400
# Train ACC: 99.91
# Epoch: 085/400 | Batch 000/391 | Cost: 0.0082 |Seed 000 |
# Epoch: 085/400 | Batch 150/391 | Cost: 0.0183 |Seed 000 |
# Epoch: 085/400 | Batch 300/391 | Cost: 0.0069 |Seed 000 |
# Epoch: 085/400
# Train ACC: 99.91
# Epoch: 086/400 | Batch 000/391 | Cost: 0.0188 |Seed 000 |
# Epoch: 086/400 | Batch 150/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 086/400 | Batch 300/391 | Cost: 0.0070 |Seed 000 |
# Epoch: 086/400
# Train ACC: 99.92
# Epoch: 087/400 | Batch 000/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 087/400 | Batch 150/391 | Cost: 0.0090 |Seed 000 |
# Epoch: 087/400 | Batch 300/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 087/400
# Train ACC: 99.92
# Epoch: 088/400 | Batch 000/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 088/400 | Batch 150/391 | Cost: 0.0073 |Seed 000 |
# Epoch: 088/400 | Batch 300/391 | Cost: 0.0050 |Seed 000 |
# Epoch: 088/400
# Train ACC: 99.93
# Epoch: 089/400 | Batch 000/391 | Cost: 0.0233 |Seed 000 |
# Epoch: 089/400 | Batch 150/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 089/400 | Batch 300/391 | Cost: 0.0117 |Seed 000 |
# Epoch: 089/400
# Train ACC: 99.92
# Epoch: 090/400 | Batch 000/391 | Cost: 0.0058 |Seed 000 |
# Epoch: 090/400 | Batch 150/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 090/400 | Batch 300/391 | Cost: 0.0198 |Seed 000 |
# Epoch: 090/400
# Train ACC: 99.93
# Epoch: 091/400 | Batch 000/391 | Cost: 0.0013 |Seed 000 |
# Epoch: 091/400 | Batch 150/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 091/400 | Batch 300/391 | Cost: 0.0074 |Seed 000 |
# Epoch: 091/400
# Train ACC: 99.93
# Epoch: 092/400 | Batch 000/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 092/400 | Batch 150/391 | Cost: 0.0086 |Seed 000 |
# Epoch: 092/400 | Batch 300/391 | Cost: 0.0200 |Seed 000 |
# Epoch: 092/400
# Train ACC: 99.94
# Epoch: 093/400 | Batch 000/391 | Cost: 0.0011 |Seed 000 |
# Epoch: 093/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 093/400 | Batch 300/391 | Cost: 0.0063 |Seed 000 |
# Epoch: 093/400
# Train ACC: 99.94
# Epoch: 094/400 | Batch 000/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 094/400 | Batch 150/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 094/400 | Batch 300/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 094/400
# Train ACC: 99.94
# Epoch: 095/400 | Batch 000/391 | Cost: 0.0129 |Seed 000 |
# Epoch: 095/400 | Batch 150/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 095/400 | Batch 300/391 | Cost: 0.0085 |Seed 000 |
# Epoch: 095/400
# Train ACC: 99.94
# Epoch: 096/400 | Batch 000/391 | Cost: 0.0078 |Seed 000 |
# Epoch: 096/400 | Batch 150/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 096/400 | Batch 300/391 | Cost: 0.0066 |Seed 000 |
# Epoch: 096/400
# Train ACC: 99.94
# Epoch: 097/400 | Batch 000/391 | Cost: 0.0077 |Seed 000 |
# Epoch: 097/400 | Batch 150/391 | Cost: 0.0120 |Seed 000 |
# Epoch: 097/400 | Batch 300/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 097/400
# Train ACC: 99.95
# Epoch: 098/400 | Batch 000/391 | Cost: 0.0124 |Seed 000 |
# Epoch: 098/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 098/400 | Batch 300/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 098/400
# Train ACC: 99.95
# Epoch: 099/400 | Batch 000/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 099/400 | Batch 150/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 099/400 | Batch 300/391 | Cost: 0.0143 |Seed 000 |
# Epoch: 099/400
# Train ACC: 99.95
# Epoch: 100/400 | Batch 000/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 100/400 | Batch 150/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 100/400 | Batch 300/391 | Cost: 0.0141 |Seed 000 |
# Epoch: 100/400
# Train ACC: 99.95
# Epoch: 101/400 | Batch 000/391 | Cost: 0.0287 |Seed 000 |
# Epoch: 101/400 | Batch 150/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 101/400 | Batch 300/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 101/400
# Train ACC: 99.95
# Epoch: 102/400 | Batch 000/391 | Cost: 0.0139 |Seed 000 |
# Epoch: 102/400 | Batch 150/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 102/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 102/400
# Train ACC: 99.95
# Epoch: 103/400 | Batch 000/391 | Cost: 0.0065 |Seed 000 |
# Epoch: 103/400 | Batch 150/391 | Cost: 0.0077 |Seed 000 |
# Epoch: 103/400 | Batch 300/391 | Cost: 0.0027 |Seed 000 |
# Epoch: 103/400
# Train ACC: 99.95
# Epoch: 104/400 | Batch 000/391 | Cost: 0.0192 |Seed 000 |
# Epoch: 104/400 | Batch 150/391 | Cost: 0.0107 |Seed 000 |
# Epoch: 104/400 | Batch 300/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 104/400
# Train ACC: 99.95
# Epoch: 105/400 | Batch 000/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 105/400 | Batch 150/391 | Cost: 0.0063 |Seed 000 |
# Epoch: 105/400 | Batch 300/391 | Cost: 0.0075 |Seed 000 |
# Epoch: 105/400
# Train ACC: 99.95
# Epoch: 106/400 | Batch 000/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 106/400 | Batch 150/391 | Cost: 0.0063 |Seed 000 |
# Epoch: 106/400 | Batch 300/391 | Cost: 0.0073 |Seed 000 |
# Epoch: 106/400
# Train ACC: 99.95
# Epoch: 107/400 | Batch 000/391 | Cost: 0.0016 |Seed 000 |
# Epoch: 107/400 | Batch 150/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 107/400 | Batch 300/391 | Cost: 0.0060 |Seed 000 |
# Epoch: 107/400
# Train ACC: 99.95
# Epoch: 108/400 | Batch 000/391 | Cost: 0.0310 |Seed 000 |
# Epoch: 108/400 | Batch 150/391 | Cost: 0.0174 |Seed 000 |
# Epoch: 108/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 108/400
# Train ACC: 99.95
# Epoch: 109/400 | Batch 000/391 | Cost: 0.0108 |Seed 000 |
# Epoch: 109/400 | Batch 150/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 109/400 | Batch 300/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 109/400
# Train ACC: 99.95
# Epoch: 110/400 | Batch 000/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 110/400 | Batch 150/391 | Cost: 0.0074 |Seed 000 |
# Epoch: 110/400 | Batch 300/391 | Cost: 0.0089 |Seed 000 |
# Epoch: 110/400
# Train ACC: 99.95
# Epoch: 111/400 | Batch 000/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 111/400 | Batch 150/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 111/400 | Batch 300/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 111/400
# Train ACC: 99.95
# Epoch: 112/400 | Batch 000/391 | Cost: 0.0080 |Seed 000 |
# Epoch: 112/400 | Batch 150/391 | Cost: 0.0206 |Seed 000 |
# Epoch: 112/400 | Batch 300/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 112/400
# Train ACC: 99.95
# Epoch: 113/400 | Batch 000/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 113/400 | Batch 150/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 113/400 | Batch 300/391 | Cost: 0.0149 |Seed 000 |
# Epoch: 113/400
# Train ACC: 99.95
# Epoch: 114/400 | Batch 000/391 | Cost: 0.0121 |Seed 000 |
# Epoch: 114/400 | Batch 150/391 | Cost: 0.0081 |Seed 000 |
# Epoch: 114/400 | Batch 300/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 114/400
# Train ACC: 99.95
# Epoch: 115/400 | Batch 000/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 115/400 | Batch 150/391 | Cost: 0.0175 |Seed 000 |
# Epoch: 115/400 | Batch 300/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 115/400
# Train ACC: 99.95
# Epoch: 116/400 | Batch 000/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 116/400 | Batch 150/391 | Cost: 0.0258 |Seed 000 |
# Epoch: 116/400 | Batch 300/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 116/400
# Train ACC: 99.95
# Epoch: 117/400 | Batch 000/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 117/400 | Batch 150/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 117/400 | Batch 300/391 | Cost: 0.0094 |Seed 000 |
# Epoch: 117/400
# Train ACC: 99.95
# Epoch: 118/400 | Batch 000/391 | Cost: 0.0085 |Seed 000 |
# Epoch: 118/400 | Batch 150/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 118/400 | Batch 300/391 | Cost: 0.0217 |Seed 000 |
# Epoch: 118/400
# Train ACC: 99.95
# Epoch: 119/400 | Batch 000/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 119/400 | Batch 150/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 119/400 | Batch 300/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 119/400
# Train ACC: 99.95
# Epoch: 120/400 | Batch 000/391 | Cost: 0.0068 |Seed 000 |
# Epoch: 120/400 | Batch 150/391 | Cost: 0.0067 |Seed 000 |
# Epoch: 120/400 | Batch 300/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 120/400
# Train ACC: 99.95
# Epoch: 121/400 | Batch 000/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 121/400 | Batch 150/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 121/400 | Batch 300/391 | Cost: 0.0075 |Seed 000 |
# Epoch: 121/400
# Train ACC: 99.95
# Epoch: 122/400 | Batch 000/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 122/400 | Batch 150/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 122/400 | Batch 300/391 | Cost: 0.0016 |Seed 000 |
# Epoch: 122/400
# Train ACC: 99.95
# Epoch: 123/400 | Batch 000/391 | Cost: 0.0070 |Seed 000 |
# Epoch: 123/400 | Batch 150/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 123/400 | Batch 300/391 | Cost: 0.0032 |Seed 000 |
# Epoch: 123/400
# Train ACC: 99.95
# Epoch: 124/400 | Batch 000/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 124/400 | Batch 150/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 124/400 | Batch 300/391 | Cost: 0.0110 |Seed 000 |
# Epoch: 124/400
# Train ACC: 99.95
# Epoch: 125/400 | Batch 000/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 125/400 | Batch 150/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 125/400 | Batch 300/391 | Cost: 0.0148 |Seed 000 |
# Epoch: 125/400
# Train ACC: 99.95
# Epoch: 126/400 | Batch 000/391 | Cost: 0.0123 |Seed 000 |
# Epoch: 126/400 | Batch 150/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 126/400 | Batch 300/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 126/400
# Train ACC: 99.95
# Epoch: 127/400 | Batch 000/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 127/400 | Batch 150/391 | Cost: 0.0058 |Seed 000 |
# Epoch: 127/400 | Batch 300/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 127/400
# Train ACC: 99.95
# Epoch: 128/400 | Batch 000/391 | Cost: 0.0053 |Seed 000 |
# Epoch: 128/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 128/400 | Batch 300/391 | Cost: 0.0109 |Seed 000 |
# Epoch: 128/400
# Train ACC: 99.95
# Epoch: 129/400 | Batch 000/391 | Cost: 0.0099 |Seed 000 |
# Epoch: 129/400 | Batch 150/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 129/400 | Batch 300/391 | Cost: 0.0130 |Seed 000 |
# Epoch: 129/400
# Train ACC: 99.95
# Epoch: 130/400 | Batch 000/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 130/400 | Batch 150/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 130/400 | Batch 300/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 130/400
# Train ACC: 99.95
# Epoch: 131/400 | Batch 000/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 131/400 | Batch 150/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 131/400 | Batch 300/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 131/400
# Train ACC: 99.95
# Epoch: 132/400 | Batch 000/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 132/400 | Batch 150/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 132/400 | Batch 300/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 132/400
# Train ACC: 99.95
# Epoch: 133/400 | Batch 000/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 133/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 133/400 | Batch 300/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 133/400
# Train ACC: 99.95
# Epoch: 134/400 | Batch 000/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 134/400 | Batch 150/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 134/400 | Batch 300/391 | Cost: 0.0050 |Seed 000 |
# Epoch: 134/400
# Train ACC: 99.95
# Epoch: 135/400 | Batch 000/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 135/400 | Batch 150/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 135/400 | Batch 300/391 | Cost: 0.0049 |Seed 000 |
# Epoch: 135/400
# Train ACC: 99.95
# Epoch: 136/400 | Batch 000/391 | Cost: 0.0073 |Seed 000 |
# Epoch: 136/400 | Batch 150/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 136/400 | Batch 300/391 | Cost: 0.0049 |Seed 000 |
# Epoch: 136/400
# Train ACC: 99.95
# Epoch: 137/400 | Batch 000/391 | Cost: 0.0089 |Seed 000 |
# Epoch: 137/400 | Batch 150/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 137/400 | Batch 300/391 | Cost: 0.0069 |Seed 000 |
# Epoch: 137/400
# Train ACC: 99.95
# Epoch: 138/400 | Batch 000/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 138/400 | Batch 150/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 138/400 | Batch 300/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 138/400
# Train ACC: 99.95
# Epoch: 139/400 | Batch 000/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 139/400 | Batch 150/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 139/400 | Batch 300/391 | Cost: 0.0211 |Seed 000 |
# Epoch: 139/400
# Train ACC: 99.95
# Epoch: 140/400 | Batch 000/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 140/400 | Batch 150/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 140/400 | Batch 300/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 140/400
# Train ACC: 99.95
# Epoch: 141/400 | Batch 000/391 | Cost: 0.0089 |Seed 000 |
# Epoch: 141/400 | Batch 150/391 | Cost: 0.0142 |Seed 000 |
# Epoch: 141/400 | Batch 300/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 141/400
# Train ACC: 99.95
# Epoch: 142/400 | Batch 000/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 142/400 | Batch 150/391 | Cost: 0.0054 |Seed 000 |
# Epoch: 142/400 | Batch 300/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 142/400
# Train ACC: 99.95
# Epoch: 143/400 | Batch 000/391 | Cost: 0.0062 |Seed 000 |
# Epoch: 143/400 | Batch 150/391 | Cost: 0.0070 |Seed 000 |
# Epoch: 143/400 | Batch 300/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 143/400
# Train ACC: 99.95
# Epoch: 144/400 | Batch 000/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 144/400 | Batch 150/391 | Cost: 0.0143 |Seed 000 |
# Epoch: 144/400 | Batch 300/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 144/400
# Train ACC: 99.95
# Epoch: 145/400 | Batch 000/391 | Cost: 0.0091 |Seed 000 |
# Epoch: 145/400 | Batch 150/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 145/400 | Batch 300/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 145/400
# Train ACC: 99.95
# Epoch: 146/400 | Batch 000/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 146/400 | Batch 150/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 146/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 146/400
# Train ACC: 99.95
# Epoch: 147/400 | Batch 000/391 | Cost: 0.0152 |Seed 000 |
# Epoch: 147/400 | Batch 150/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 147/400 | Batch 300/391 | Cost: 0.0170 |Seed 000 |
# Epoch: 147/400
# Train ACC: 99.95
# Epoch: 148/400 | Batch 000/391 | Cost: 0.0189 |Seed 000 |
# Epoch: 148/400 | Batch 150/391 | Cost: 0.0200 |Seed 000 |
# Epoch: 148/400 | Batch 300/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 148/400
# Train ACC: 99.95
# Epoch: 149/400 | Batch 000/391 | Cost: 0.0256 |Seed 000 |
# Epoch: 149/400 | Batch 150/391 | Cost: 0.0049 |Seed 000 |
# Epoch: 149/400 | Batch 300/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 149/400
# Train ACC: 99.95
# Epoch: 150/400 | Batch 000/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 150/400 | Batch 150/391 | Cost: 0.0077 |Seed 000 |
# Epoch: 150/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 150/400
# Train ACC: 99.96
# Epoch: 151/400 | Batch 000/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 151/400 | Batch 150/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 151/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 151/400
# Train ACC: 99.95
# Epoch: 152/400 | Batch 000/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 152/400 | Batch 150/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 152/400 | Batch 300/391 | Cost: 0.0053 |Seed 000 |
# Epoch: 152/400
# Train ACC: 99.95
# Epoch: 153/400 | Batch 000/391 | Cost: 0.0069 |Seed 000 |
# Epoch: 153/400 | Batch 150/391 | Cost: 0.0027 |Seed 000 |
# Epoch: 153/400 | Batch 300/391 | Cost: 0.0131 |Seed 000 |
# Epoch: 153/400
# Train ACC: 99.95
# Epoch: 154/400 | Batch 000/391 | Cost: 0.0048 |Seed 000 |
# Epoch: 154/400 | Batch 150/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 154/400 | Batch 300/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 154/400
# Train ACC: 99.95
# Epoch: 155/400 | Batch 000/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 155/400 | Batch 150/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 155/400 | Batch 300/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 155/400
# Train ACC: 99.95
# Epoch: 156/400 | Batch 000/391 | Cost: 0.0032 |Seed 000 |
# Epoch: 156/400 | Batch 150/391 | Cost: 0.0197 |Seed 000 |
# Epoch: 156/400 | Batch 300/391 | Cost: 0.0086 |Seed 000 |
# Epoch: 156/400
# Train ACC: 99.95
# Epoch: 157/400 | Batch 000/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 157/400 | Batch 150/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 157/400 | Batch 300/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 157/400
# Train ACC: 99.95
# Epoch: 158/400 | Batch 000/391 | Cost: 0.0079 |Seed 000 |
# Epoch: 158/400 | Batch 150/391 | Cost: 0.0050 |Seed 000 |
# Epoch: 158/400 | Batch 300/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 158/400
# Train ACC: 99.95
# Epoch: 159/400 | Batch 000/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 159/400 | Batch 150/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 159/400 | Batch 300/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 159/400
# Train ACC: 99.95
# Epoch: 160/400 | Batch 000/391 | Cost: 0.0136 |Seed 000 |
# Epoch: 160/400 | Batch 150/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 160/400 | Batch 300/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 160/400
# Train ACC: 99.95
# Epoch: 161/400 | Batch 000/391 | Cost: 0.0095 |Seed 000 |
# Epoch: 161/400 | Batch 150/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 161/400 | Batch 300/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 161/400
# Train ACC: 99.95
# Epoch: 162/400 | Batch 000/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 162/400 | Batch 150/391 | Cost: 0.0126 |Seed 000 |
# Epoch: 162/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 162/400
# Train ACC: 99.95
# Epoch: 163/400 | Batch 000/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 163/400 | Batch 150/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 163/400 | Batch 300/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 163/400
# Train ACC: 99.95
# Epoch: 164/400 | Batch 000/391 | Cost: 0.0163 |Seed 000 |
# Epoch: 164/400 | Batch 150/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 164/400 | Batch 300/391 | Cost: 0.0050 |Seed 000 |
# Epoch: 164/400
# Train ACC: 99.95
# Epoch: 165/400 | Batch 000/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 165/400 | Batch 150/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 165/400 | Batch 300/391 | Cost: 0.0048 |Seed 000 |
# Epoch: 165/400
# Train ACC: 99.95
# Epoch: 166/400 | Batch 000/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 166/400 | Batch 150/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 166/400 | Batch 300/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 166/400
# Train ACC: 99.95
# Epoch: 167/400 | Batch 000/391 | Cost: 0.0074 |Seed 000 |
# Epoch: 167/400 | Batch 150/391 | Cost: 0.0126 |Seed 000 |
# Epoch: 167/400 | Batch 300/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 167/400
# Train ACC: 99.95
# Epoch: 168/400 | Batch 000/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 168/400 | Batch 150/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 168/400 | Batch 300/391 | Cost: 0.0280 |Seed 000 |
# Epoch: 168/400
# Train ACC: 99.95
# Epoch: 169/400 | Batch 000/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 169/400 | Batch 150/391 | Cost: 0.0099 |Seed 000 |
# Epoch: 169/400 | Batch 300/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 169/400
# Train ACC: 99.95
# Epoch: 170/400 | Batch 000/391 | Cost: 0.0048 |Seed 000 |
# Epoch: 170/400 | Batch 150/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 170/400 | Batch 300/391 | Cost: 0.0011 |Seed 000 |
# Epoch: 170/400
# Train ACC: 99.95
# Epoch: 171/400 | Batch 000/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 171/400 | Batch 150/391 | Cost: 0.0066 |Seed 000 |
# Epoch: 171/400 | Batch 300/391 | Cost: 0.0063 |Seed 000 |
# Epoch: 171/400
# Train ACC: 99.95
# Epoch: 172/400 | Batch 000/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 172/400 | Batch 150/391 | Cost: 0.0062 |Seed 000 |
# Epoch: 172/400 | Batch 300/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 172/400
# Train ACC: 99.95
# Epoch: 173/400 | Batch 000/391 | Cost: 0.0013 |Seed 000 |
# Epoch: 173/400 | Batch 150/391 | Cost: 0.0130 |Seed 000 |
# Epoch: 173/400 | Batch 300/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 173/400
# Train ACC: 99.95
# Epoch: 174/400 | Batch 000/391 | Cost: 0.0109 |Seed 000 |
# Epoch: 174/400 | Batch 150/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 174/400 | Batch 300/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 174/400
# Train ACC: 99.95
# Epoch: 175/400 | Batch 000/391 | Cost: 0.0075 |Seed 000 |
# Epoch: 175/400 | Batch 150/391 | Cost: 0.0049 |Seed 000 |
# Epoch: 175/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 175/400
# Train ACC: 99.95
# Epoch: 176/400 | Batch 000/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 176/400 | Batch 150/391 | Cost: 0.0066 |Seed 000 |
# Epoch: 176/400 | Batch 300/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 176/400
# Train ACC: 99.95
# Epoch: 177/400 | Batch 000/391 | Cost: 0.0190 |Seed 000 |
# Epoch: 177/400 | Batch 150/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 177/400 | Batch 300/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 177/400
# Train ACC: 99.95
# Epoch: 178/400 | Batch 000/391 | Cost: 0.0088 |Seed 000 |
# Epoch: 178/400 | Batch 150/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 178/400 | Batch 300/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 178/400
# Train ACC: 99.95
# Epoch: 179/400 | Batch 000/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 179/400 | Batch 150/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 179/400 | Batch 300/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 179/400
# Train ACC: 99.95
# Epoch: 180/400 | Batch 000/391 | Cost: 0.0205 |Seed 000 |
# Epoch: 180/400 | Batch 150/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 180/400 | Batch 300/391 | Cost: 0.0058 |Seed 000 |
# Epoch: 180/400
# Train ACC: 99.95
# Epoch: 181/400 | Batch 000/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 181/400 | Batch 150/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 181/400 | Batch 300/391 | Cost: 0.0058 |Seed 000 |
# Epoch: 181/400
# Train ACC: 99.95
# Epoch: 182/400 | Batch 000/391 | Cost: 0.0305 |Seed 000 |
# Epoch: 182/400 | Batch 150/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 182/400 | Batch 300/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 182/400
# Train ACC: 99.95
# Epoch: 183/400 | Batch 000/391 | Cost: 0.0009 |Seed 000 |
# Epoch: 183/400 | Batch 150/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 183/400 | Batch 300/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 183/400
# Train ACC: 99.95
# Epoch: 184/400 | Batch 000/391 | Cost: 0.0123 |Seed 000 |
# Epoch: 184/400 | Batch 150/391 | Cost: 0.0077 |Seed 000 |
# Epoch: 184/400 | Batch 300/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 184/400
# Train ACC: 99.95
# Epoch: 185/400 | Batch 000/391 | Cost: 0.0098 |Seed 000 |
# Epoch: 185/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 185/400 | Batch 300/391 | Cost: 0.0180 |Seed 000 |
# Epoch: 185/400
# Train ACC: 99.95
# Epoch: 186/400 | Batch 000/391 | Cost: 0.0124 |Seed 000 |
# Epoch: 186/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 186/400 | Batch 300/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 186/400
# Train ACC: 99.95
# Epoch: 187/400 | Batch 000/391 | Cost: 0.0103 |Seed 000 |
# Epoch: 187/400 | Batch 150/391 | Cost: 0.0071 |Seed 000 |
# Epoch: 187/400 | Batch 300/391 | Cost: 0.0076 |Seed 000 |
# Epoch: 187/400
# Train ACC: 99.95
# Epoch: 188/400 | Batch 000/391 | Cost: 0.0059 |Seed 000 |
# Epoch: 188/400 | Batch 150/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 188/400 | Batch 300/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 188/400
# Train ACC: 99.95
# Epoch: 189/400 | Batch 000/391 | Cost: 0.0067 |Seed 000 |
# Epoch: 189/400 | Batch 150/391 | Cost: 0.0048 |Seed 000 |
# Epoch: 189/400 | Batch 300/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 189/400
# Train ACC: 99.95
# Epoch: 190/400 | Batch 000/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 190/400 | Batch 150/391 | Cost: 0.0068 |Seed 000 |
# Epoch: 190/400 | Batch 300/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 190/400
# Train ACC: 99.96
# Epoch: 191/400 | Batch 000/391 | Cost: 0.0079 |Seed 000 |
# Epoch: 191/400 | Batch 150/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 191/400 | Batch 300/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 191/400
# Train ACC: 99.96
# Epoch: 192/400 | Batch 000/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 192/400 | Batch 150/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 192/400 | Batch 300/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 192/400
# Train ACC: 99.96
# Epoch: 193/400 | Batch 000/391 | Cost: 0.0066 |Seed 000 |
# Epoch: 193/400 | Batch 150/391 | Cost: 0.0115 |Seed 000 |
# Epoch: 193/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 193/400
# Train ACC: 99.96
# Epoch: 194/400 | Batch 000/391 | Cost: 0.0210 |Seed 000 |
# Epoch: 194/400 | Batch 150/391 | Cost: 0.0083 |Seed 000 |
# Epoch: 194/400 | Batch 300/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 194/400
# Train ACC: 99.96
# Epoch: 195/400 | Batch 000/391 | Cost: 0.0094 |Seed 000 |
# Epoch: 195/400 | Batch 150/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 195/400 | Batch 300/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 195/400
# Train ACC: 99.96
# Epoch: 196/400 | Batch 000/391 | Cost: 0.0060 |Seed 000 |
# Epoch: 196/400 | Batch 150/391 | Cost: 0.0065 |Seed 000 |
# Epoch: 196/400 | Batch 300/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 196/400
# Train ACC: 99.96
# Epoch: 197/400 | Batch 000/391 | Cost: 0.0069 |Seed 000 |
# Epoch: 197/400 | Batch 150/391 | Cost: 0.0059 |Seed 000 |
# Epoch: 197/400 | Batch 300/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 197/400
# Train ACC: 99.96
# Epoch: 198/400 | Batch 000/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 198/400 | Batch 150/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 198/400 | Batch 300/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 198/400
# Train ACC: 99.96
# Epoch: 199/400 | Batch 000/391 | Cost: 0.0059 |Seed 000 |
# Epoch: 199/400 | Batch 150/391 | Cost: 0.0052 |Seed 000 |
# Epoch: 199/400 | Batch 300/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 199/400
# Train ACC: 99.96
# Epoch: 200/400 | Batch 000/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 200/400 | Batch 150/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 200/400 | Batch 300/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 200/400
# Train ACC: 99.96
# Epoch: 201/400 | Batch 000/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 201/400 | Batch 150/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 201/400 | Batch 300/391 | Cost: 0.0079 |Seed 000 |
# Epoch: 201/400
# Train ACC: 99.96
# Epoch: 202/400 | Batch 000/391 | Cost: 0.0124 |Seed 000 |
# Epoch: 202/400 | Batch 150/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 202/400 | Batch 300/391 | Cost: 0.0140 |Seed 000 |
# Epoch: 202/400
# Train ACC: 99.96
# Epoch: 203/400 | Batch 000/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 203/400 | Batch 150/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 203/400 | Batch 300/391 | Cost: 0.0013 |Seed 000 |
# Epoch: 203/400
# Train ACC: 99.96
# Epoch: 204/400 | Batch 000/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 204/400 | Batch 150/391 | Cost: 0.0063 |Seed 000 |
# Epoch: 204/400 | Batch 300/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 204/400
# Train ACC: 99.96
# Epoch: 205/400 | Batch 000/391 | Cost: 0.0077 |Seed 000 |
# Epoch: 205/400 | Batch 150/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 205/400 | Batch 300/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 205/400
# Train ACC: 99.96
# Epoch: 206/400 | Batch 000/391 | Cost: 0.0109 |Seed 000 |
# Epoch: 206/400 | Batch 150/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 206/400 | Batch 300/391 | Cost: 0.0076 |Seed 000 |
# Epoch: 206/400
# Train ACC: 99.96
# Epoch: 207/400 | Batch 000/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 207/400 | Batch 150/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 207/400 | Batch 300/391 | Cost: 0.0075 |Seed 000 |
# Epoch: 207/400
# Train ACC: 99.96
# Epoch: 208/400 | Batch 000/391 | Cost: 0.0117 |Seed 000 |
# Epoch: 208/400 | Batch 150/391 | Cost: 0.0013 |Seed 000 |
# Epoch: 208/400 | Batch 300/391 | Cost: 0.0032 |Seed 000 |
# Epoch: 208/400
# Train ACC: 99.96
# Epoch: 209/400 | Batch 000/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 209/400 | Batch 150/391 | Cost: 0.0053 |Seed 000 |
# Epoch: 209/400 | Batch 300/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 209/400
# Train ACC: 99.96
# Epoch: 210/400 | Batch 000/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 210/400 | Batch 150/391 | Cost: 0.0053 |Seed 000 |
# Epoch: 210/400 | Batch 300/391 | Cost: 0.0066 |Seed 000 |
# Epoch: 210/400
# Train ACC: 99.96
# Epoch: 211/400 | Batch 000/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 211/400 | Batch 150/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 211/400 | Batch 300/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 211/400
# Train ACC: 99.96
# Epoch: 212/400 | Batch 000/391 | Cost: 0.0027 |Seed 000 |
# Epoch: 212/400 | Batch 150/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 212/400 | Batch 300/391 | Cost: 0.0052 |Seed 000 |
# Epoch: 212/400
# Train ACC: 99.96
# Epoch: 213/400 | Batch 000/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 213/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 213/400 | Batch 300/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 213/400
# Train ACC: 99.96
# Epoch: 214/400 | Batch 000/391 | Cost: 0.0013 |Seed 000 |
# Epoch: 214/400 | Batch 150/391 | Cost: 0.0074 |Seed 000 |
# Epoch: 214/400 | Batch 300/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 214/400
# Train ACC: 99.96
# Epoch: 215/400 | Batch 000/391 | Cost: 0.0012 |Seed 000 |
# Epoch: 215/400 | Batch 150/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 215/400 | Batch 300/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 215/400
# Train ACC: 99.96
# Epoch: 216/400 | Batch 000/391 | Cost: 0.0013 |Seed 000 |
# Epoch: 216/400 | Batch 150/391 | Cost: 0.0032 |Seed 000 |
# Epoch: 216/400 | Batch 300/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 216/400
# Train ACC: 99.96
# Epoch: 217/400 | Batch 000/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 217/400 | Batch 150/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 217/400 | Batch 300/391 | Cost: 0.0090 |Seed 000 |
# Epoch: 217/400
# Train ACC: 99.96
# Epoch: 218/400 | Batch 000/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 218/400 | Batch 150/391 | Cost: 0.0075 |Seed 000 |
# Epoch: 218/400 | Batch 300/391 | Cost: 0.0088 |Seed 000 |
# Epoch: 218/400
# Train ACC: 99.96
# Epoch: 219/400 | Batch 000/391 | Cost: 0.0052 |Seed 000 |
# Epoch: 219/400 | Batch 150/391 | Cost: 0.0063 |Seed 000 |
# Epoch: 219/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 219/400
# Train ACC: 99.96
# Epoch: 220/400 | Batch 000/391 | Cost: 0.0130 |Seed 000 |
# Epoch: 220/400 | Batch 150/391 | Cost: 0.0027 |Seed 000 |
# Epoch: 220/400 | Batch 300/391 | Cost: 0.0104 |Seed 000 |
# Epoch: 220/400
# Train ACC: 99.96
# Epoch: 221/400 | Batch 000/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 221/400 | Batch 150/391 | Cost: 0.0054 |Seed 000 |
# Epoch: 221/400 | Batch 300/391 | Cost: 0.0011 |Seed 000 |
# Epoch: 221/400
# Train ACC: 99.96
# Epoch: 222/400 | Batch 000/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 222/400 | Batch 150/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 222/400 | Batch 300/391 | Cost: 0.0075 |Seed 000 |
# Epoch: 222/400
# Train ACC: 99.96
# Epoch: 223/400 | Batch 000/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 223/400 | Batch 150/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 223/400 | Batch 300/391 | Cost: 0.0077 |Seed 000 |
# Epoch: 223/400
# Train ACC: 99.96
# Epoch: 224/400 | Batch 000/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 224/400 | Batch 150/391 | Cost: 0.0110 |Seed 000 |
# Epoch: 224/400 | Batch 300/391 | Cost: 0.0065 |Seed 000 |
# Epoch: 224/400
# Train ACC: 99.96
# Epoch: 225/400 | Batch 000/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 225/400 | Batch 150/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 225/400 | Batch 300/391 | Cost: 0.0075 |Seed 000 |
# Epoch: 225/400
# Train ACC: 99.96
# Epoch: 226/400 | Batch 000/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 226/400 | Batch 150/391 | Cost: 0.0054 |Seed 000 |
# Epoch: 226/400 | Batch 300/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 226/400
# Train ACC: 99.96
# Epoch: 227/400 | Batch 000/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 227/400 | Batch 150/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 227/400 | Batch 300/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 227/400
# Train ACC: 99.96
# Epoch: 228/400 | Batch 000/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 228/400 | Batch 150/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 228/400 | Batch 300/391 | Cost: 0.0074 |Seed 000 |
# Epoch: 228/400
# Train ACC: 99.96
# Epoch: 229/400 | Batch 000/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 229/400 | Batch 150/391 | Cost: 0.0105 |Seed 000 |
# Epoch: 229/400 | Batch 300/391 | Cost: 0.0097 |Seed 000 |
# Epoch: 229/400
# Train ACC: 99.96
# Epoch: 230/400 | Batch 000/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 230/400 | Batch 150/391 | Cost: 0.0090 |Seed 000 |
# Epoch: 230/400 | Batch 300/391 | Cost: 0.0074 |Seed 000 |
# Epoch: 230/400
# Train ACC: 99.96
# Epoch: 231/400 | Batch 000/391 | Cost: 0.0060 |Seed 000 |
# Epoch: 231/400 | Batch 150/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 231/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 231/400
# Train ACC: 99.96
# Epoch: 232/400 | Batch 000/391 | Cost: 0.0012 |Seed 000 |
# ...
# Epoch: 323/400 | Batch 300/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 323/400
# Train ACC: 99.96
# Epoch: 324/400 | Batch 000/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 324/400 | Batch 150/391 | Cost: 0.0076 |Seed 000 |
# Epoch: 324/400 | Batch 300/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 324/400
# Train ACC: 99.96
# Epoch: 325/400 | Batch 000/391 | Cost: 0.0174 |Seed 000 |
# Epoch: 325/400 | Batch 150/391 | Cost: 0.0144 |Seed 000 |
# Epoch: 325/400 | Batch 300/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 325/400
# Train ACC: 99.96
# Epoch: 326/400 | Batch 000/391 | Cost: 0.0162 |Seed 000 |
# Epoch: 326/400 | Batch 150/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 326/400 | Batch 300/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 326/400
# Train ACC: 99.96
# Epoch: 327/400 | Batch 000/391 | Cost: 0.0199 |Seed 000 |
# Epoch: 327/400 | Batch 150/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 327/400 | Batch 300/391 | Cost: 0.0073 |Seed 000 |
# Epoch: 327/400
# Train ACC: 99.96
# Epoch: 328/400 | Batch 000/391 | Cost: 0.0060 |Seed 000 |
# Epoch: 328/400 | Batch 150/391 | Cost: 0.0134 |Seed 000 |
# Epoch: 328/400 | Batch 300/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 328/400
# Train ACC: 99.96
# Epoch: 329/400 | Batch 000/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 329/400 | Batch 150/391 | Cost: 0.0277 |Seed 000 |
# Epoch: 329/400 | Batch 300/391 | Cost: 0.0027 |Seed 000 |
# Epoch: 329/400
# Train ACC: 99.96
# Epoch: 330/400 | Batch 000/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 330/400 | Batch 150/391 | Cost: 0.0084 |Seed 000 |
# Epoch: 330/400 | Batch 300/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 330/400
# Train ACC: 99.96
# Epoch: 331/400 | Batch 000/391 | Cost: 0.0246 |Seed 000 |
# Epoch: 331/400 | Batch 150/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 331/400 | Batch 300/391 | Cost: 0.0048 |Seed 000 |
# Epoch: 331/400
# Train ACC: 99.96
# Epoch: 332/400 | Batch 000/391 | Cost: 0.0142 |Seed 000 |
# Epoch: 332/400 | Batch 150/391 | Cost: 0.0096 |Seed 000 |
# Epoch: 332/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 332/400
# Train ACC: 99.96
# Epoch: 333/400 | Batch 000/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 333/400 | Batch 150/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 333/400 | Batch 300/391 | Cost: 0.0138 |Seed 000 |
# Epoch: 333/400
# Train ACC: 99.96
# Epoch: 334/400 | Batch 000/391 | Cost: 0.0062 |Seed 000 |
# Epoch: 334/400 | Batch 150/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 334/400 | Batch 300/391 | Cost: 0.0169 |Seed 000 |
# Epoch: 334/400
# Train ACC: 99.96
# Epoch: 335/400 | Batch 000/391 | Cost: 0.0015 |Seed 000 |
# Epoch: 335/400 | Batch 150/391 | Cost: 0.0078 |Seed 000 |
# Epoch: 335/400 | Batch 300/391 | Cost: 0.0176 |Seed 000 |
# Epoch: 335/400
# Train ACC: 99.96
# Epoch: 336/400 | Batch 000/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 336/400 | Batch 150/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 336/400 | Batch 300/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 336/400
# Train ACC: 99.96
# Epoch: 337/400 | Batch 000/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 337/400 | Batch 150/391 | Cost: 0.0171 |Seed 000 |
# Epoch: 337/400 | Batch 300/391 | Cost: 0.0050 |Seed 000 |
# Epoch: 337/400
# Train ACC: 99.96
# Epoch: 338/400 | Batch 000/391 | Cost: 0.0040 |Seed 000 |
# Epoch: 338/400 | Batch 150/391 | Cost: 0.0203 |Seed 000 |
# Epoch: 338/400 | Batch 300/391 | Cost: 0.0063 |Seed 000 |
# Epoch: 338/400
# Train ACC: 99.96
# Epoch: 339/400 | Batch 000/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 339/400 | Batch 150/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 339/400 | Batch 300/391 | Cost: 0.0065 |Seed 000 |
# Epoch: 339/400
# Train ACC: 99.96
# Epoch: 340/400 | Batch 000/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 340/400 | Batch 150/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 340/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 340/400
# Train ACC: 99.96
# Epoch: 341/400 | Batch 000/391 | Cost: 0.0059 |Seed 000 |
# Epoch: 341/400 | Batch 150/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 341/400 | Batch 300/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 341/400
# Train ACC: 99.96
# Epoch: 342/400 | Batch 000/391 | Cost: 0.0261 |Seed 000 |
# Epoch: 342/400 | Batch 150/391 | Cost: 0.0117 |Seed 000 |
# Epoch: 342/400 | Batch 300/391 | Cost: 0.0086 |Seed 000 |
# Epoch: 342/400
# Train ACC: 99.96
# Epoch: 343/400 | Batch 000/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 343/400 | Batch 150/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 343/400 | Batch 300/391 | Cost: 0.0194 |Seed 000 |
# Epoch: 343/400
# Train ACC: 99.96
# Epoch: 344/400 | Batch 000/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 344/400 | Batch 150/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 344/400 | Batch 300/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 344/400
# Train ACC: 99.96
# Epoch: 345/400 | Batch 000/391 | Cost: 0.0116 |Seed 000 |
# Epoch: 345/400 | Batch 150/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 345/400 | Batch 300/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 345/400
# Train ACC: 99.96
# Epoch: 346/400 | Batch 000/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 346/400 | Batch 150/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 346/400 | Batch 300/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 346/400
# Train ACC: 99.96
# Epoch: 347/400 | Batch 000/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 347/400 | Batch 150/391 | Cost: 0.0073 |Seed 000 |
# Epoch: 347/400 | Batch 300/391 | Cost: 0.0032 |Seed 000 |
# Epoch: 347/400
# Train ACC: 99.96
# Epoch: 348/400 | Batch 000/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 348/400 | Batch 150/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 348/400 | Batch 300/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 348/400
# Train ACC: 99.96
# Epoch: 349/400 | Batch 000/391 | Cost: 0.0053 |Seed 000 |
# Epoch: 349/400 | Batch 150/391 | Cost: 0.0184 |Seed 000 |
# Epoch: 349/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 349/400
# Train ACC: 99.96
# Epoch: 350/400 | Batch 000/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 350/400 | Batch 150/391 | Cost: 0.0032 |Seed 000 |
# Epoch: 350/400 | Batch 300/391 | Cost: 0.0049 |Seed 000 |
# Epoch: 350/400
# Train ACC: 99.96
# Epoch: 351/400 | Batch 000/391 | Cost: 0.0054 |Seed 000 |
# Epoch: 351/400 | Batch 150/391 | Cost: 0.0052 |Seed 000 |
# Epoch: 351/400 | Batch 300/391 | Cost: 0.0076 |Seed 000 |
# Epoch: 351/400
# Train ACC: 99.96
# Epoch: 352/400 | Batch 000/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 352/400 | Batch 150/391 | Cost: 0.0016 |Seed 000 |
# Epoch: 352/400 | Batch 300/391 | Cost: 0.0084 |Seed 000 |
# Epoch: 352/400
# Train ACC: 99.96
# Epoch: 353/400 | Batch 000/391 | Cost: 0.0011 |Seed 000 |
# Epoch: 353/400 | Batch 150/391 | Cost: 0.0072 |Seed 000 |
# Epoch: 353/400 | Batch 300/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 353/400
# Train ACC: 99.96
# Epoch: 354/400 | Batch 000/391 | Cost: 0.0091 |Seed 000 |
# Epoch: 354/400 | Batch 150/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 354/400 | Batch 300/391 | Cost: 0.0026 |Seed 000 |
# Epoch: 354/400
# Train ACC: 99.96
# Epoch: 355/400 | Batch 000/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 355/400 | Batch 150/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 355/400 | Batch 300/391 | Cost: 0.0196 |Seed 000 |
# Epoch: 355/400
# Train ACC: 99.96
# Epoch: 356/400 | Batch 000/391 | Cost: 0.0091 |Seed 000 |
# Epoch: 356/400 | Batch 150/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 356/400 | Batch 300/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 356/400
# Train ACC: 99.96
# Epoch: 357/400 | Batch 000/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 357/400 | Batch 150/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 357/400 | Batch 300/391 | Cost: 0.0079 |Seed 000 |
# Epoch: 357/400
# Train ACC: 99.96
# Epoch: 358/400 | Batch 000/391 | Cost: 0.0077 |Seed 000 |
# Epoch: 358/400 | Batch 150/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 358/400 | Batch 300/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 358/400
# Train ACC: 99.96
# Epoch: 359/400 | Batch 000/391 | Cost: 0.0085 |Seed 000 |
# Epoch: 359/400 | Batch 150/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 359/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 359/400
# Train ACC: 99.96
# Epoch: 360/400 | Batch 000/391 | Cost: 0.0231 |Seed 000 |
# Epoch: 360/400 | Batch 150/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 360/400 | Batch 300/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 360/400
# Train ACC: 99.96
# Epoch: 361/400 | Batch 000/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 361/400 | Batch 150/391 | Cost: 0.0011 |Seed 000 |
# Epoch: 361/400 | Batch 300/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 361/400
# Train ACC: 99.96
# Epoch: 362/400 | Batch 000/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 362/400 | Batch 150/391 | Cost: 0.0042 |Seed 000 |
# Epoch: 362/400 | Batch 300/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 362/400
# Train ACC: 99.96
# Epoch: 363/400 | Batch 000/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 363/400 | Batch 150/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 363/400 | Batch 300/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 363/400
# Train ACC: 99.96
# Epoch: 364/400 | Batch 000/391 | Cost: 0.0102 |Seed 000 |
# Epoch: 364/400 | Batch 150/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 364/400 | Batch 300/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 364/400
# Train ACC: 99.96
# Epoch: 365/400 | Batch 000/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 365/400 | Batch 150/391 | Cost: 0.0069 |Seed 000 |
# Epoch: 365/400 | Batch 300/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 365/400
# Train ACC: 99.96
# Epoch: 366/400 | Batch 000/391 | Cost: 0.0035 |Seed 000 |
# Epoch: 366/400 | Batch 150/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 366/400 | Batch 300/391 | Cost: 0.0061 |Seed 000 |
# Epoch: 366/400
# Train ACC: 99.96
# Epoch: 367/400 | Batch 000/391 | Cost: 0.0029 |Seed 000 |
# Epoch: 367/400 | Batch 150/391 | Cost: 0.0071 |Seed 000 |
# Epoch: 367/400 | Batch 300/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 367/400
# Train ACC: 99.96
# Epoch: 368/400 | Batch 000/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 368/400 | Batch 150/391 | Cost: 0.0014 |Seed 000 |
# Epoch: 368/400 | Batch 300/391 | Cost: 0.0072 |Seed 000 |
# Epoch: 368/400
# Train ACC: 99.96
# Epoch: 369/400 | Batch 000/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 369/400 | Batch 150/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 369/400 | Batch 300/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 369/400
# Train ACC: 99.96
# Epoch: 370/400 | Batch 000/391 | Cost: 0.0005 |Seed 000 |
# Epoch: 370/400 | Batch 150/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 370/400 | Batch 300/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 370/400
# Train ACC: 99.96
# Epoch: 371/400 | Batch 000/391 | Cost: 0.0067 |Seed 000 |
# Epoch: 371/400 | Batch 150/391 | Cost: 0.0229 |Seed 000 |
# Epoch: 371/400 | Batch 300/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 371/400
# Train ACC: 99.96
# Epoch: 372/400 | Batch 000/391 | Cost: 0.0353 |Seed 000 |
# Epoch: 372/400 | Batch 150/391 | Cost: 0.0245 |Seed 000 |
# Epoch: 372/400 | Batch 300/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 372/400
# Train ACC: 99.96
# Epoch: 373/400 | Batch 000/391 | Cost: 0.0068 |Seed 000 |
# Epoch: 373/400 | Batch 150/391 | Cost: 0.0096 |Seed 000 |
# Epoch: 373/400 | Batch 300/391 | Cost: 0.0021 |Seed 000 |
# Epoch: 373/400
# Train ACC: 99.96
# Epoch: 374/400 | Batch 000/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 374/400 | Batch 150/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 374/400 | Batch 300/391 | Cost: 0.0135 |Seed 000 |
# Epoch: 374/400
# Train ACC: 99.96
# Epoch: 375/400 | Batch 000/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 375/400 | Batch 150/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 375/400 | Batch 300/391 | Cost: 0.0048 |Seed 000 |
# Epoch: 375/400
# Train ACC: 99.96
# Epoch: 376/400 | Batch 000/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 376/400 | Batch 150/391 | Cost: 0.0049 |Seed 000 |
# Epoch: 376/400 | Batch 300/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 376/400
# Train ACC: 99.96
# Epoch: 377/400 | Batch 000/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 377/400 | Batch 150/391 | Cost: 0.0039 |Seed 000 |
# Epoch: 377/400 | Batch 300/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 377/400
# Train ACC: 99.96
# Epoch: 378/400 | Batch 000/391 | Cost: 0.0082 |Seed 000 |
# Epoch: 378/400 | Batch 150/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 378/400 | Batch 300/391 | Cost: 0.0103 |Seed 000 |
# Epoch: 378/400
# Train ACC: 99.96
# Epoch: 379/400 | Batch 000/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 379/400 | Batch 150/391 | Cost: 0.0099 |Seed 000 |
# Epoch: 379/400 | Batch 300/391 | Cost: 0.0050 |Seed 000 |
# Epoch: 379/400
# Train ACC: 99.96
# Epoch: 380/400 | Batch 000/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 380/400 | Batch 150/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 380/400 | Batch 300/391 | Cost: 0.0089 |Seed 000 |
# Epoch: 380/400
# Train ACC: 99.96
# Epoch: 381/400 | Batch 000/391 | Cost: 0.0024 |Seed 000 |
# Epoch: 381/400 | Batch 150/391 | Cost: 0.0132 |Seed 000 |
# Epoch: 381/400 | Batch 300/391 | Cost: 0.0176 |Seed 000 |
# Epoch: 381/400
# Train ACC: 99.96
# Epoch: 382/400 | Batch 000/391 | Cost: 0.0169 |Seed 000 |
# Epoch: 382/400 | Batch 150/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 382/400 | Batch 300/391 | Cost: 0.0078 |Seed 000 |
# Epoch: 382/400
# Train ACC: 99.96
# Epoch: 383/400 | Batch 000/391 | Cost: 0.0082 |Seed 000 |
# Epoch: 383/400 | Batch 150/391 | Cost: 0.0056 |Seed 000 |
# Epoch: 383/400 | Batch 300/391 | Cost: 0.0080 |Seed 000 |
# Epoch: 383/400
# Train ACC: 99.96
# Epoch: 384/400 | Batch 000/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 384/400 | Batch 150/391 | Cost: 0.0020 |Seed 000 |
# Epoch: 384/400 | Batch 300/391 | Cost: 0.0102 |Seed 000 |
# Epoch: 384/400
# Train ACC: 99.96
# Epoch: 385/400 | Batch 000/391 | Cost: 0.0054 |Seed 000 |
# Epoch: 385/400 | Batch 150/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 385/400 | Batch 300/391 | Cost: 0.0044 |Seed 000 |
# Epoch: 385/400
# Train ACC: 99.96
# Epoch: 386/400 | Batch 000/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 386/400 | Batch 150/391 | Cost: 0.0027 |Seed 000 |
# Epoch: 386/400 | Batch 300/391 | Cost: 0.0030 |Seed 000 |
# Epoch: 386/400
# Train ACC: 99.96
# Epoch: 387/400 | Batch 000/391 | Cost: 0.0150 |Seed 000 |
# Epoch: 387/400 | Batch 150/391 | Cost: 0.0294 |Seed 000 |
# Epoch: 387/400 | Batch 300/391 | Cost: 0.0102 |Seed 000 |
# Epoch: 387/400
# Train ACC: 99.96
# Epoch: 388/400 | Batch 000/391 | Cost: 0.0072 |Seed 000 |
# Epoch: 388/400 | Batch 150/391 | Cost: 0.0022 |Seed 000 |
# Epoch: 388/400 | Batch 300/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 388/400
# Train ACC: 99.96
# Epoch: 389/400 | Batch 000/391 | Cost: 0.0106 |Seed 000 |
# Epoch: 389/400 | Batch 150/391 | Cost: 0.0086 |Seed 000 |
# Epoch: 389/400 | Batch 300/391 | Cost: 0.0048 |Seed 000 |
# Epoch: 389/400
# Train ACC: 99.96
# Epoch: 390/400 | Batch 000/391 | Cost: 0.0060 |Seed 000 |
# Epoch: 390/400 | Batch 150/391 | Cost: 0.0025 |Seed 000 |
# Epoch: 390/400 | Batch 300/391 | Cost: 0.0041 |Seed 000 |
# Epoch: 390/400
# Train ACC: 99.96
# Epoch: 391/400 | Batch 000/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 391/400 | Batch 150/391 | Cost: 0.0171 |Seed 000 |
# Epoch: 391/400 | Batch 300/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 391/400
# Train ACC: 99.96
# Epoch: 392/400 | Batch 000/391 | Cost: 0.0023 |Seed 000 |
# Epoch: 392/400 | Batch 150/391 | Cost: 0.0019 |Seed 000 |
# Epoch: 392/400 | Batch 300/391 | Cost: 0.0127 |Seed 000 |
# Epoch: 392/400
# Train ACC: 99.96
# Epoch: 393/400 | Batch 000/391 | Cost: 0.0017 |Seed 000 |
# Epoch: 393/400 | Batch 150/391 | Cost: 0.0184 |Seed 000 |
# Epoch: 393/400 | Batch 300/391 | Cost: 0.0046 |Seed 000 |
# Epoch: 393/400
# Train ACC: 99.96
# Epoch: 394/400 | Batch 000/391 | Cost: 0.0047 |Seed 000 |
# Epoch: 394/400 | Batch 150/391 | Cost: 0.0037 |Seed 000 |
# Epoch: 394/400 | Batch 300/391 | Cost: 0.0043 |Seed 000 |
# Epoch: 394/400
# Train ACC: 99.96
# Epoch: 395/400 | Batch 000/391 | Cost: 0.0055 |Seed 000 |
# Epoch: 395/400 | Batch 150/391 | Cost: 0.0033 |Seed 000 |
# Epoch: 395/400 | Batch 300/391 | Cost: 0.0071 |Seed 000 |
# Epoch: 395/400
# Train ACC: 99.96
# Epoch: 396/400 | Batch 000/391 | Cost: 0.0106 |Seed 000 |
# Epoch: 396/400 | Batch 150/391 | Cost: 0.0036 |Seed 000 |
# Epoch: 396/400 | Batch 300/391 | Cost: 0.0051 |Seed 000 |
# Epoch: 396/400
# Train ACC: 99.96
# Epoch: 397/400 | Batch 000/391 | Cost: 0.0038 |Seed 000 |
# Epoch: 397/400 | Batch 150/391 | Cost: 0.0059 |Seed 000 |
# Epoch: 397/400 | Batch 300/391 | Cost: 0.0018 |Seed 000 |
# Epoch: 397/400
# Train ACC: 99.96
# Epoch: 398/400 | Batch 000/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 398/400 | Batch 150/391 | Cost: 0.0057 |Seed 000 |
# Epoch: 398/400 | Batch 300/391 | Cost: 0.0179 |Seed 000 |
# Epoch: 398/400
# Train ACC: 99.96
# Epoch: 399/400 | Batch 000/391 | Cost: 0.0034 |Seed 000 |
# Epoch: 399/400 | Batch 150/391 | Cost: 0.0031 |Seed 000 |
# Epoch: 399/400 | Batch 300/391 | Cost: 0.0045 |Seed 000 |
# Epoch: 399/400
# Train ACC: 99.96
# Epoch: 400/400 | Batch 000/391 | Cost: 0.0064 |Seed 000 |
# Epoch: 400/400 | Batch 150/391 | Cost: 0.0085 |Seed 000 |
# Epoch: 400/400 | Batch 300/391 | Cost: 0.0028 |Seed 000 |
# Epoch: 400/400
# Train ACC: 99.96
